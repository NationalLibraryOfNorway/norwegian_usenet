# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2


def load_content(path):
    return pd.read_csv(path).sort_values("both", ascending=False)


full = load_content("../data/ia_nwa_content_comparison.csv")
filtered = load_content("../data/ia_nwa_content_comparison_date_filtered.csv")

# %% [markdown]
# # IA vs NWA Content Comparison
#
# Exact-body-match message overlap between IA and NWA, for full IA data and IA filtered to the NWA date span.

# %%
for label, df in [("Full IA", full), ("IA date-filtered", filtered)]:
    print(f"\n{label}")
    display(df.head(20))
# Out:
# Full IA
#             newsgroup  ia_only  nwa_only  both
# 230    no.marked.data    74369     21020  1081
# 141        no.general   167003     75170  1000
# 14       no.alt.flame    30662     18760   984
# 227         no.marked    45019     24940   752
# 297          no.slekt     9573      7520   585
# 259             no.pc    81282     24811   499
# 239         no.musikk    49362     26874   450
# 273       no.religion    48581     19923   392
# 224            no.mac    42666     21582   301
# 114           no.film    21638     12162   244
# 350         no.vitser    13375     10189   225
# 303          no.spill    18337     11900   216
# 217          no.linux    53528     15967   213
# 82           no.audio    20990     10048   177
# 321         no.sykkel    11267      3822   131
# 306  no.sport.diverse    10410      6101   128
# 332           no.test    69957      3037   116
# 344           no.unix     7750      3814   101
# 86    no.biz.annonser    10974      3313    93
# 232    no.marked.jobb     5280      3438    85
# IA date-filtered
#             newsgroup  ia_only  nwa_only  both
# 187    no.marked.data    26961     21026  1075
# 114        no.general    75058     75170  1000
# 12       no.alt.flame    14972     18762   982
# 184         no.marked    18179     24942   750
# 249          no.slekt     4355      7520   585
# 214             no.pc    30474     24811   499
# 196         no.musikk    22380     26875   449
# 228       no.religion    23371     19923   392
# 181            no.mac    17334     21583   300
# 91            no.film     9066     12162   244
# 299         no.vitser     7308     10190   224
# 255          no.spill    10423     11900   216
# 176          no.linux    13189     15967   213
# 62           no.audio     8231     10048   177
# 272         no.sykkel     5518      3822   131
# 258  no.sport.diverse     4239      6101   128
# 294           no.unix     4225      3814   101
# 66    no.biz.annonser     4804      3314    92
# 189    no.marked.jobb     2729      3438    85
# 201   no.news.diverse     7287      9108    84

# %%
for label, df in [("Full IA", full), ("IA date-filtered", filtered)]:
    print(f"{label}:")
    print(f"  IA only:  {df['ia_only'].sum():,}")
    print(f"  NWA only: {df['nwa_only'].sum():,}")
    print(f"  Both:     {df['both'].sum():,}")
    print()
# Out:
# Full IA:
#   IA only:  5,945,762
#   NWA only: 595,894
#   Both:     9,056
#
# IA date-filtered:
#   IA only:  558,134
#   NWA only: 595,974
#   Both:     8,976

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, (label, df) in zip(axes, [("Full IA", full), ("IA date-filtered", filtered)]):
    venn2(
        subsets=(df["ia_only"].sum(), df["nwa_only"].sum(), df["both"].sum()),
        set_labels=("IA", "NWA"),
        ax=ax,
    )
    ax.set_title(f"Message overlap — {label}\n(exact body match)")
plt.tight_layout()
plt.show()

# %%
sum_i = (filtered.nwa_only + filtered.ia_only).sort_values(ascending=False).index
sortby_sum = filtered.loc[sum_i]
sortby_sum = sortby_sum[(sortby_sum.nwa_only > 1) & (sortby_sum.ia_only > 1)]
top_50_sum = sortby_sum.head(50)
top_50_sum.to_json(
    "../data/newsgroups_for_selection.jsonl", index=False, lines=True, orient="records"
)
